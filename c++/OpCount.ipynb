# %%
import numpy as np
from matplotlib.pyplot import step, legend, xlim, ylim, show
a=np.loadtxt('histo_opcount_total.dat')
plot(a[:,0],a[:,1])
a=np.loadtxt('histo_opcount0.dat')
plot(a[:,0],a[:,1])
a=np.loadtxt('histo_opcount1.dat')
plot(a[:,0],a[:,1])
plt.xlim (0,100)
# Out:
# (0, 100)

# %%
a=np.loadtxt('histo_trace_first_over_sec_term.dat')
plot(a[:,0],a[:,1],'-o') 
plt.xlim (0,0.1)
# Out:
# (0, 0.1)

# %%
a=np.loadtxt('histo_trace_first_term_trace.dat')
#b=np.loadtxt('histo_trace_first_term_trace.N.dat')
f, axarr = plt.subplots(1,2, sharex=True)
axarr[0].plot(a[:,0],a[:,1])
axarr[0].set_title('Sharing X axis')
#axarr[1].plot(b[:,0],b[:,1])
#plot(a[:,0],a[:,1]) 
plt.xlim (0.8,1)
#plt.ylim (0,0.01)
# Out:
# (0.8, 1)

# %%
a=np.loadtxt('histo_dominant_block_bound.dat')
#a1=np.loadtxt('histo_dominant_block_bound_v1.dat')
b=np.loadtxt('histo_dominant_block_trace.dat')
f, axarr = plt.subplots(1,3, sharex=False)
axarr[0].plot(a[:,0],a[:,1],'-o')
#axarr[1].plot(a1[:,0],a1[:,1],'-o')
axarr[2].plot(b[:,0],b[:,1],'-o')
axarr[0].set_xlim(0,100)
axarr[1].set_xlim(0,150)
axarr[2].set_xlim(0,150)
f.set_figwidth(10)

# %%
a=np.loadtxt('histo_dominant_block_energy_bound.dat')
b=np.loadtxt('histo_dominant_block_energy_trace.dat')
f, axarr = plt.subplots(1,2, sharex=True)
axarr[0].plot(a[:,0],a[:,1],'-o')
axarr[1].plot(b[:,0],b[:,1],'-o')
axarr[0].set_xlim(0,20)
f.set_figwidth(10)

# %%
a=np.loadtxt('histo_nblock_at_root.dat')
b=np.loadtxt('histo_n_block_examined_first_pass.dat')
c=np.loadtxt('histo_n_block_kept.dat')
f, axarr = plt.subplots(1,3, sharex=True)
axarr[0].plot(a[:,0],a[:,1],'o')
axarr[1].plot(b[:,0],b[:,1],'o')
axarr[2].plot(c[:,0],c[:,1],'o')
f.set_figwidth(10)
plt.xlim (0.,10)
# Out:
# (0.0, 10)

# %%
a=np.loadtxt('histo_appel.dat')
b=np.loadtxt('histo_appel2.dat')
c=np.loadtxt('histo_appel3.dat')
f, axarr = plt.subplots(1,2)
axarr[0].plot(a[:,0],a[:,1])
axarr[1].plot(b[:,0],b[:,1],'-o')
axarr[1].plot(c[:,0],c[:,1],'-o')
axarr[1].set_xlim(0,25)
f.set_figwidth(10)

# %%
a=np.loadtxt('histo_cut1.dat')
b=np.loadtxt('histo_cut2.dat')
c=np.loadtxt('histo_cut2_energy.dat')
f, axarr = plt.subplots(1,3)
axarr[0].plot(a[:,0],a[:,1])
axarr[1].plot(b[:,0],b[:,1])
axarr[2].plot(c[:,0],c[:,1])
plt.xlim (0.,300)
axarr[2].set_xlim(0,50)#plt.ylim (0,0.01)
f.set_figwidth(10)
